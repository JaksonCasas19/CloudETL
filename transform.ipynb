# %% [markdown]
# ### Importar Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Cargar Datos

# %%
pathInput = 's3://etl-wids21/Extract/'

# %%
data = pd.read_csv(pathInput+'charts.csv')

# %% [markdown]
# ### Transformación

# %%
data.head()
# Out:
#    rank                            song                     artist  last-week  \
# 0     1                          Butter                        BTS        1.0
# 1     2                        Good 4 U             Olivia Rodrigo        2.0
# 2     3                      Levitating  Dua Lipa Featuring DaBaby        4.0
# 3     4                    Kiss Me More     Doja Cat Featuring SZA        3.0
# 4     5  Montero (Call Me By Your Name)                  Lil Nas X        8.0
#
#    peak-rank  weeks-on-board        date
# 0          1               7  2021-07-17
# 1          1               8  2021-07-17
# 2          2              40  2021-07-17
# 3          3              13  2021-07-17
# 4          1              15  2021-07-17

# %%
data.describe()
# Out:
#                 rank      last-week      peak-rank  weeks-on-board
# count  328487.000000  296422.000000  328487.000000   328487.000000
# mean       50.500933      47.601197      41.007154        9.152472
# std        28.866094      28.056956      29.349247        7.596439
# min         1.000000       1.000000       1.000000        1.000000
# 25%        26.000000      23.000000      14.000000        4.000000
# 50%        51.000000      47.000000      38.000000        7.000000
# 75%        76.000000      72.000000      65.000000       13.000000
# max       100.000000     100.000000     100.000000       87.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328487 entries, 0 to 328486
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   rank            328487 non-null  int64
#  1   song            328487 non-null  object
#  2   artist          328487 non-null  object
#  3   last-week       296422 non-null  float64
#  4   peak-rank       328487 non-null  int64
#  5   weeks-on-board  328487 non-null  int64
#  6   date            328487 non-null  object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 17.5+ MB

# %%
data[data['last-week'].isnull()]
# Out:
#         rank                                 song  \
# 13        14                    Am I The Only One
# 48        49                         Wasting Time
# 72        73                             Renegade
# 80        81                          Cry No More
# 81        82                              Essence
# ...      ...                                  ...
# 328482    96                        Over And Over
# 328483    97                     I Believe In You
# 328484    98                      Little Serenade
# 328485    99  I'll Get By (As Long As I Have You)
# 328486   100                                 Judy
#
#                                         artist  last-week  peak-rank  \
# 13                                 Aaron Lewis        NaN         14
# 48                Brent Faiyaz Featuring Drake        NaN         49
# 72      Big Red Machine Featuring Taylor Swift        NaN         73
# 80         G Herbo Featuring Polo G & Lil Tjay        NaN         81
# 81                       Wizkid Featuring Tems        NaN         82
# ...                                        ...        ...        ...
# 328482                         Thurston Harris        NaN         96
# 328483                         Robert & Johnny        NaN         97
# 328484                       The Ames Brothers        NaN         98
# 328485                          Billy Williams        NaN         99
# 328486                         Frankie Vaughan        NaN        100
#
#         weeks-on-board        date
# 13                   1  2021-07-17
# 48                   1  2021-07-17
# 72                   1  2021-07-17
# 80                   1  2021-07-17
# 81                   1  2021-07-17
# ...                ...         ...
# 328482               1  1958-08-04
# 328483               1  1958-08-04
# 328484               1  1958-08-04
# 328485               1  1958-08-04
# 328486               1  1958-08-04
#
# [32065 rows x 7 columns]

# %% [markdown]
# Los valores nulos en la columna 'last-week' representan las canciones que aparecen por primera vez en la lista del top 100, por lo tanto no cuentan con una posición en el ranking de la semana anterior.
#
# Estos valores serán reemplazados por un 0 en la columna:

# %%
data['last-week'].fillna(0, inplace=True)
data['last-week'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Se creará una columna que describe el comportamiento de la canción de acuerdo a su posición actual y la posición de la última semana:

# %%
data["efficiency"] = np.where(data['last-week'] - data['rank'] > 0, 'Up', 
         (np.where(data['last-week'] - data['rank'] < 0, 'Down', 'Equal')))

# %%
data.sample(5)
# Out:
#         rank                        song                        artist  \
# 267840    54  Can't Help Falling In Love                    Al Martino
# 291880    94     I've Cried My Last Tear                    The O'Jays
# 20464     65                  Most Girls              Hailee Steinfeld
# 285717    31                   Born Free                Roger Williams
# 3651      52                          24  Money Man Featuring Lil Baby
#
#         last-week  peak-rank  weeks-on-board        date efficiency
# 267840       51.0         51               7  1970-03-21       Down
# 291880       98.0         94               2  1965-08-14         Up
# 20464        72.0         58              11  2017-08-19         Up
# 285717       41.0         31               8  1966-10-15         Up
# 3651         51.0         49              11  2020-11-07       Down

# %% [markdown]
# ### Guardar datos

# %%
pathOutput = 's3://etl-wids21/Load/'

# %%
data.to_csv(pathOutput+'dataCurada.csv')
